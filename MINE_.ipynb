# %% [markdown]
# <a href="https://colab.research.google.com/github/cankish/DeepWalk_implementaion/blob/master/MINE_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mutual Infromation Neural Estimator(MINE) and some applications
#
#
# *   Scalable
# *   Consistent
# *   Differentiable
# (Proofs in the paper)
#
# #Applications:
# * Mode dropping in GANs
# * Improve inference and reconstructions in Bi-directional GANs(ALI)
# * Information Bottleneck (cotinuous setting)

# %%
# from utils import process_tweet, lookup
import pdb
import pickle # loading the data
import gzip

#tensorflow
import tensorflow as tf
from tensorflow import keras


#pytorch
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
from torch import nn, optim
import torch.nn.functional as F
import torch.utils.data as data   #dataloader

from torchvision import datasets, transforms
from torchvision.utils import save_image

# import torch_geometric

#utils
import numpy as np
import pandas as pd

#vis
import matplotlib.pyplot as plt
# import plotly
import networkx
import seaborn as sns

#dev tools
import json
import datetime as datetime
import time
from pathlib import Path
###os
from os import getcwd, chdir
import glob, os, sys, re



#nlp
import nltk
import string
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords, twitter_samples

#sklearn
from sklearn.model_selection import train_test_split 
import sklearn.linear_model
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import sklearn.datasets


#opencv
import cv2
from PIL import Image

#checks/versions

print(f"Tensorflow version: {tf.__version__}")
print(f"Pytorch version: {torch.__version__}")



import shutil
# shutil.make_archive('images', 'zip', 'images')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Tensorflow version: 2.3.0
# Pytorch version: 1.6.0+cu101

# %% [markdown]
# Mutual Information:Primal Formulation
#
#
# I(X,Z) = H(Z) - H(Z|X) = H(X) - H(X|Z)
#
# I(X,Z) = *DKL*(Pxz||Pz Px)
#
# Usefulness:
#
# *   Feature Selection
# *   Evaluating GANs
# *   Decoupling r.v.(ICA, Disentangling, regularization)
# *   Coupling r.v.(Infomax, I.B.)
#
#
# Estimating mutual information:
#
# *   Non-parametric estimation
# *   Variational Approach
# *   ANICA

# %%
def get_data():
  x = np.random.multivariate_normal( mean=[0,0],
                                     cov=[[1,0],[0,1]],
                                     size = 300
                                    )
  
  z = np.random.multivariate_normal( mean=[0,0],
                                     cov=[[1,0.8],[0.8,1]],
                                     size = 300,
                                    )
  
  data = (x,z)
  return data

def pre_process():

# %%
sns.set()

def show(data):
  x = data[0]
  z = data[1]

  plt.subplot(121)
  plt.title('X', fontsize=14)
  sns.scatterplot(x=x[:,0],y=x[:,1])


  plt.subplot(122)
  plt.title('Z', fontsize=14)
  sns.scatterplot(x=z[:,0],y=z[:,1])

# %%
data = get_data()
show(data)

#hyperparameters

input_dim = 
hidden_dim = 
lr = 1e-3
wd = 1e-4
optimizer = 
loss = 
epochs = 
batch_size =

# %%
def weight_inti():
  
class statistics_network(nn.Module):
  def __inti__(self, input_dim=2 , hidden_dim=3):
    super(statistics_network,self).__init__()
    self.fc1 = nn.Linear(input_dim, hidden_dim)
    self.fc2 = nn.Linear(hidden_dim, hidden_dim)
    self.fc3 = nn.Linear(hidden_dim, 1)

    weight_init(sefl.fc1)
    weight_init(sefl.fc2)
    weight_init(sefl.fc3)


    

  def forward(self, X):
    X = F.relu(self.fc1(X))
    X = F.relu(self.fc2(X))
    X = self.fc3(X)
    return X

# %%
mine = statistics_network(4,3)

# %%
def mutual_infromation(mine, pxz, px, pz):

  T  = mine(pxz)
  eT = torch.exp(mine(px,pz))

  mi = torch.mean(T) - torch.mean(eT)

  dic = {
           "T":T
           "eT":eT
           "mi": mi
        }

  return dic





def train_mine:
  



def test_mine:

# %%
def save_model:

# %% [markdown]
# Method of moments

# %% [markdown]
# Monte carlo sampling, MC Tree search
